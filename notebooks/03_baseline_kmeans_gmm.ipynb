# %% [markdown]
# # 03_baseline_kmeans_gmm
#
# Author: Rishabh Gokhe
#
# This notebook is part of the Unsupervised Marine Regime Discovery workflow.

# %%
import numpy as np
import pandas as pd

from src.core.config import load_config
from src.pipeline.regime_pipeline import run_pipeline

cfg = load_config('configs/config.yml')
cfg

# %%
# TODO: add phase-specific experiments and plots
